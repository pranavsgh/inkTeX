# %% [markdown]
# # Explore im2latex-100k
#
# Quick look at sample images and their LaTeX labels from the im2latex-100k dataset. (Pranav)

# %%
# TODO: load a few samples from backend/data and display image + formula pairs
